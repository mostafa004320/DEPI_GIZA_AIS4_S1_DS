# %% [markdown]
# # Task 1.
# - Calculate Factorial using recursion

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def factorial(n: int) -> int:
    if n < 0:
        raise ValueError("Factorial is not defined for negative numbers")
    if n in (0, 1):
        return 1
    return n * factorial(n - 1)

factorial(5)
# Out:
# 120

# %% [markdown]
# # Task 2.
# - Write a function that takes a number and return True if this number is prime and False if not.

# %%
def is_prime(n: int) -> bool:
    if n < 2:
        return False
    if n == 2:
        return True
    if n % 2 == 0:
        return False
    
    i = 3
    while i * i <= n:
        if n % i == 0:
            return False
        i += 2
    return True

is_prime(20), is_prime(19), is_prime(1)
# Out:
# (False, True, False)

# %% [markdown]
# # Task 3.
# - Write a function that takes two numbers and return a list of common dividors

# %%
def dividors(num1, num2):
    mn = min(num1, num2)
    common_dividors = []
    for i in range(1, mn+1):
        if num1 % i == 0 and num2 % i ==0:
            common_dividors.append(i)
    return common_dividors

dividors(20, 10)
# Out:
# [1, 2, 5, 10]

# %%
eveen=[]
def even_fun(num):
    for i in range(num):
        if i % 2==0:
            print(eveen.append(num))
    return eveen

# %% [markdown]
# # Task 4.
# - Given two strings, write a program that efficiently finds the longest common subsequence
#
# - **Ex:** str1 = "Welcome to Machine Learning Diploma" str2 = "I am studying a Machine Learning Course" --> Machine Learning

# %%
def longest_common_phrase(str1: str, str2: str) -> str:
    w1 = str1.split()
    w2 = str2.split()
    n, m = len(w1), len(w2)

    dp = [[0] * (m + 1) for _ in range(n + 1)]
    best_len = 0
    best_end = 0  # end index in w1

    for i in range(1, n + 1):
        for j in range(1, m + 1):
            if w1[i - 1] == w2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1
                if dp[i][j] > best_len:
                    best_len = dp[i][j]
                    best_end = i
            else:
                dp[i][j] = 0

    return " ".join(w1[best_end - best_len: best_end])

str1 = "Welcome to Machine Learning Diploma"
str2 = "I am studying a Machine Learning Course"
longest_common_phrase(str1, str2)
# Out:
# 'Machine Learning'

# %% [markdown]
# # Task 5.
# - Write a function that will take a given string and reverse the order of words.
#
# - **Ex:** “Hello world” → ”world Hello”

# %%
def reverse_words(s: str) -> str:
    return " ".join(s.split()[::-1])

reverse_words("Hello world")
# Out:
# 'world Hello'

# %% [markdown]
# # Task 6.
# - Create a program that generates a random password of a given length.
# - Hint: use random module → import random → random.randrange

# %%
import random
import string

def generate_password(length: int) -> str:
    if length <= 0:
        raise ValueError("length must be positive")

    chars = string.ascii_letters + string.digits + "!@#$%^&*"
    return "".join(random.choice(chars) for _ in range(length))

generate_password(8)
# Out:
# 'XiZYK^&u'

# %%
import random
import string

class PasswordGenerator:
    def __init__(self, length: int):
        if length <= 0:
            raise ValueError("length must be positive")
        self.length = length
        self.chars = string.ascii_letters + string.digits + "!@#$%^&*"

    def generate(self) -> str:
        return "".join(random.choice(self.chars) for _ in range(self.length))

gen = PasswordGenerator(10)
gen.generate()
# Out:
# 'tGv5$xVV^e'

# %%
class person:
    def __init__(self, movement, color_name="red"):
        self.movement = movement
        self.color_name = color_name

    def run(self):
        print(f"i am {self.movement} and have this color name {self.color_name}")

    def __str__(self):
        return f"person(movement={self.movement}, color_name={self.color_name})"


p = person('reversed')
print(p)     
p.run()
# Out:
# person(movement=reversed, color_name=red)
# i am reversed and have this color name red

# %%
if __name__ == "__main__":
    password_length = 8
    random_password = generate_password(password_length)
    print(random_password)
# Out:
# LtJFFGMv

# %% [markdown]
# # Task 7.
# - Write a Python program to find all the unique words and count the frequency of occurrence from a given list of strings
#
# - **Ex:** ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]  → {'Ali': 4, 'Welcome': 1, 'No': 3, 'Hi': 2}

# %%
from collections import Counter

words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
counts = dict(Counter(words))
counts
# Out:
# {'Welcome': 1, 'Ali': 4, 'Hi': 2, 'No': 3}

# %%
# another solution
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
unique_words = set(words)

for word in unique_words:
    print(f"{word}:{words.count(word)}")
# Out:
# Hi:2
# No:3
# Welcome:1
# Ali:4

# %% [markdown]
# # Task 9.
# - Implement a basic chatbot that can respond to user input with predefined responses

# %% [markdown]
# CONVERT IT TO CLASS STRUCTURE

# %%
import random

class Chatbot:
    def __init__(self):
        self.responses = {
            "hello": ["Hello!", "Hi there!", "Greetings!"],
            "how are you": ["I'm doing well, thank you!", "I'm fine, how about you?"],
            "goodbye": ["Goodbye!", "See you later!", "Farewell!"],
            "default": ["I'm sorry, I didn't understand.", "Could you please rephrase that?"]
        }

    def get_response(self, user_input: str) -> str:
        user_input = user_input.lower()
        for key in self.responses:
            if key != "default" and key in user_input:
                return random.choice(self.responses[key])
        return random.choice(self.responses["default"])

    def run(self):
        print("Chatbot: Hi! How can I assist you today?")
        while True:
            user_input = input("User: ").strip()
            if not user_input:
                print("Chatbot:", random.choice(self.responses["default"]))
                continue

            response = self.get_response(user_input)
            print("Chatbot:", response)

            if user_input.lower() == "goodbye":
                break

bot = Chatbot()
bot.run()
# Out:
# Chatbot: Hi! How can I assist you today?
# Chatbot: I'm sorry, I didn't understand.
# Chatbot: Greetings!
# Chatbot: I'm fine, how about you?
# Chatbot: Goodbye!
