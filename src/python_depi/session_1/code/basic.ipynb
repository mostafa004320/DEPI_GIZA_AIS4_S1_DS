# %%
print("hello")
# Out:
# hello

# %%
x = 25 #this is new variable
print("my age is", x)
# Out:
# my age is 25

# %%
name = "mostafa"
age = 35
"my name is {}, and my age is {} ".format(name, age)
# Out:
# 'my name is mostafa, and my age is 35 '

# %%
f"my name is {name} and my age is {age}"
# Out:
# 'my name is mostafa and my age is 35'

# %%
name = "depi ds"
name [3]
upper_txt =name .upper()
upper_txt
# Out:
# 'DEPI DS'

# %%
name = "welcome into depi data sciense"
x = name . split()
x
# Out:
# ['welcome', 'into', 'depi', 'data', 'sciense']

# %%
print("hello\t world")
# Out:
# hello	 world
