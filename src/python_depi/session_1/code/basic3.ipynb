# %%
name = "mostafa"
print(type(name))
list_1 = list(name)
type(list_1)
# Out:
# <class 'str'>
# list

# %%
num = 5,6
list(num)
# Out:
# [5, 6]

# %%
list_1 = [1,2,3]
list_2 =[4,5,6]
list_1.extend(list_2)

# %%
list_1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list_1 = ["depi","learning","python"]
list_1.pop()
print(list_1)
# Out:
# ['depi', 'learning']

# %%
name = input("enter name")
id = input("enter id")
print(f"my name {name},my id is {id}")
# Out:
# my name ,my id is mostafa

# %%
my_list = [1,2,2,3]
my_list.index(2)
# Out:
# 1

# %%
list_one = [1,2,3,4,"DEPI","Learning",True,[1,2,3,"True",["ml","dl","ds"]]]
print(type(list_one))
# Out:
# <class 'list'>

# %%
my_list = [50,20,10,90,5,8]
my_list.sort()
print(my_list)
# Out:
# [8, 10, 20, 50, 90]

# %%
color = ["red","green","blue","yellow"]
type(color)
# Out:
# list

# %%
set_a = {1,2,3,4}
set_b = {3,4,5,6}
print(set_a.difference(set_b))
# Out:
# {1, 2}

# %%
dict_1 = {"key1":12,"key2":"python"}
dict_1["key1"] =12.9
dict_1
# Out:
# {'key1': 12.9, 'key2': 'python'}

# %%
num_1 = float(input("enter your first number:"))
num_2 = float(input("enter your second number:"))
print(f"summation:{num_1 + num_2}")
print(f"subtraction:{num_1 - num_2}")
print(f"multiplication:{num_1 * num_2}")
print(f"division:{num_1 / num_2}")
# Out:
# summation:11.0
# subtraction:-1.0
# multiplication:30.0
# division:0.8333333333333334
