# %%
#TASK 1

email = "Amit_ml@gmail.edu"
username = email.split("@")[0]
after_at = email.split("@")[1]
domain = after_at.split(".")[0]
domain_type = email.endswith(".com") * "Commercial Domain" + \
              email.endswith(".edu") * "Educational Domain"
print(username)
print(domain)
print(domain_type)
# Out:
# Amit_ml
# gmail
# Educational Domain

# %%
#TASK 2

encoded = "###!!@mocleW EPGTQ!!!6789"

core = encoded[6:18]
words = core.split()
decoded_first = words[0][::-1]
decoded_second = words[1]
print(decoded_first, decoded_second)
# Out:
# Welcom EPGTQ

# %%
#TASK 3

encoded = "&&&**$gnirtS PLIO!!@1234"

core = encoded[6:17]
words = core.split()
first = words[0][::-1]
second = words[1].replace("I", "E").replace("O", "U")
print(first, second)
print()
# Out:
# String PLEU

# %%
#TASK 4

encoded = "##$$$@!yalpstcejorp EPUVT****9887"

core = encoded[7:25]
words = core.split()
first = words[0][::-1]
second = words[1].replace("E", "A").replace("U", "O")
print(first, second)
# Out:
# projectsplay APOVT
