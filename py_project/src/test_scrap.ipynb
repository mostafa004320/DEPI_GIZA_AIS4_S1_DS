# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from bs4 import BeautifulSoup

# %%
with open ('C:/Users/DELL/OneDrive/Desktop/DEPI_DS/DEPI_GIZA_AIS4_S1_DS/py_project/src/model/home.html', 'r') as html_file:
    content = html_file.read()
    soup = BeautifulSoup(content, 'lxml')

# %%
pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    ---------- ----------------------------- 1.0/4.0 MB 3.1 MB/s eta 0:00:01
#    ------------- -------------------------- 1.3/4.0 MB 3.4 MB/s eta 0:00:01
#    -------------------------- ------------- 2.6/4.0 MB 3.6 MB/s eta 0:00:01
#    --------------------------------- ------ 3.4/4.0 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 3.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
with open ('C:/Users/DELL/OneDrive/Desktop/DEPI_DS/DEPI_GIZA_AIS4_S1_DS/py_project/src/model/home.html', 'r') as html_file:
    content = html_file.read()
    soup = BeautifulSoup(content, 'lxml')
    print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <link href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css" rel="stylesheet"/>
#   <title>
#    DEPI_R3_BNS_DS Courses
#   </title>
#   <style>
#    body {
#             background-color: #c9d7e5;
#          }
#          .header-title {
#             text-align: center;
#             margin-top: 40px;
#             margin-bottom: 40px;
#             font-weight: bold;
#             color: #0b4676;
#          }
#          .card-deck .card {
#             transition: transform 0.3s, box-shadow 0.3s;
#          }
#          .card-deck .card:hover {
#             transform: translateY(-5px);
#             box-shadow: 0 8px 20px rgba(0, 0, 0, 0.2);
#          }
#          .btn-custom {
#             background-color: #007bff;
#             border: none;
# ...

# %%
with open ('C:/Users/DELL/OneDrive/Desktop/DEPI_DS/DEPI_GIZA_AIS4_S1_DS/py_project/src/model/home.html', 'r') as html_file:
    content = html_file.read()
    soup = BeautifulSoup(content, 'lxml')
    course_html = soup.find_all('div' , class_ = 'card')
    for course in course_html:
        course_name = course.h5.text
        print(course_name)
# Out:
# Python for Beginners
# Python Web Development
# Python Machine Learning

# %%
with open ('C:/Users/DELL/OneDrive/Desktop/DEPI_DS/DEPI_GIZA_AIS4_S1_DS/py_project/src/model/home.html', 'r') as html_file:
    content = html_file.read()
    soup = BeautifulSoup(content, 'lxml')
    course_html = soup.find_all('div' , class_ = 'card')
    for course in course_html:
        course_name = course.h5.text
        course_win = course.a.text.split()[-1]
        print(f' {course_name}  costs   {course_win}')
# Out:
#  Python for Beginners  costs   $20
#  Python Web Development  costs   $30
#  Python Machine Learning  costs   $100
